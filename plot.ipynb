# %%
from matplotlib import pyplot

cnn        = [0, 0.8423, 0.8676, 0.8776, 0.9075, 0.9179, 0.9381]
cnnAndTfIdf= [0, 0.8643, 0.8856, 0.9021, 0.9256, 0.9386, 0.9691]
biLstm     = [0, 0.8912, 0.913, 0.9323, 0.9415, 0.961, 0.9826]
biLstmTfIDF= [0, 0.93, 0.95, 0.9632, 0.9715, 0.982, 0.9926]

epochs = [1, 2, 3, 4, 5, 6, 7]

# %%
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (20,10)
pyplot.plot(epochs, cnn, marker='>', label='CNN', linewidth=4)
pyplot.plot(epochs, cnnAndTfIdf, marker='>', label='CNN + TF-IDF')
pyplot.plot(epochs, biLstm, marker='>', label='Bi-LSTM')
pyplot.plot(epochs, biLstmTfIDF, marker='>', label='Bi-LSTM+TF-IDF')
pyplot.xlabel("No. of Epochs")
pyplot.ylabel("Accuracy")
pyplot.legend()
pyplot.show()
